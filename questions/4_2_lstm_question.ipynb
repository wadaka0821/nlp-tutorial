# %% [markdown]
# <a href="https://colab.research.google.com/github/wadaka0821/nlp-tutorial/blob/main/questions/4_2_lstm_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM を使った一般常識のテキスト生成
# ## 作成者：和田
# ## 最終更新日：2023/03/08

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 11.3 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, dill, responses, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.10.1 dill-0.3.6 huggingface-hub-0.12.1 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0

# %%
import torch
from torch.nn import LSTM, CrossEntropyLoss, Embedding, Linear
from torch.nn.utils.rnn import pad_sequence
from torch.optim import Adam
from datasets import load_dataset
import nltk
from tqdm import tqdm
import seaborn as sns

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
dataset = load_dataset("common_gen")
# Out:
# Downloading builder script:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.99k [00:00<?, ?B/s]
# Downloading and preparing dataset common_gen/default to /root/.cache/huggingface/datasets/common_gen/default/2020.5.30/1a9e8bdc026c41ce7a9e96260debf7d2809cb7fd63fa02b017e4fac1b00c6b23...
# Downloading data:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67389 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4018 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1497 [00:00<?, ? examples/s]
# Dataset common_gen downloaded and prepared to /root/.cache/huggingface/datasets/common_gen/default/2020.5.30/1a9e8bdc026c41ce7a9e96260debf7d2809cb7fd63fa02b017e4fac1b00c6b23. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['concept_set_idx', 'concepts', 'target'],
#         num_rows: 67389
#     })
#     validation: Dataset({
#         features: ['concept_set_idx', 'concepts', 'target'],
#         num_rows: 4018
#     })
#     test: Dataset({
#         features: ['concept_set_idx', 'concepts', 'target'],
#         num_rows: 1497
#     })
# })

# %%
dataset['train'][0] # concepts で指定された単語を使用して文(target)を生成する
# Out:
# {'concept_set_idx': 0,
#  'concepts': ['ski', 'mountain', 'skier'],
#  'target': 'Skier skis down the mountain'}

# %% [markdown]
# # 学習データから語彙の作成

# %%
UNK_TOKEN = '<UNK>' # 未知語
PAD_TOKEN = '<PAD>' # Padding 用
SOS_TOKEN = '<s>' # Start Of Sequence
EOS_TOKEN = '</s>' # End Of Sequence

def build_vocab(sents, add_unkown=True):
    """単語と id を対応させる辞書を作成

    Parameters
    ----------
    sents : list[str]
        文のリスト

    add_unkowm : bool
        未知語に対応するトークンの追加の有無

    Returns
    -------
    dict[str, int]
        単語 -> id へ変換するための辞書
    """
    vocab = {PAD_TOKEN:0, SOS_TOKEN:1, EOS_TOKEN:2}
    if add_unkown:
        vocab[UNK_TOKEN] = len(vocab)
    for sent in sents:
        tokenized_sent = nltk.tokenize.word_tokenize(sent) # 単語分割
        for word in tokenized_sent:
            if word not in vocab: # 辞書に存在していない単語のみ追加
                vocab[word] = len(vocab)
    print(f'vocabulary size is {len(vocab)}')

    return vocab

# %%
# 学習データから concepts と target のみ取得
concepts= [i['concepts'] for i in dataset['train']]
targets= [i['target'] for i in dataset['train']]

# %%
vocab = build_vocab(targets) # 語彙の作成
# Out:
# vocabulary size is 15855

# %% [markdown]
# # モデルの作成

# %%
class Text2TextModel(torch.nn.Module):
    """LSTM を用いた Encoder-Decoder モデル

    Attributes
    ----------
    vocab_size : int
        語彙のサイズ(単語数)
    hidden_size : int 
        単語の埋め込みベクトルと隠れ状態のベクトルの次元数
    embedding : torch.nn.Embedding
        単語を埋め込みベクトルへ変換するモデル
    encoder : torch.nn.RNN
        入力系列を隠れ状態に埋め込む
    decoder : torch.nn.RNN
        出力する系列を生成
    output : torch.nn.Linear
        decoder が出力したベクトル(hidden_size, )を(vocab_size, )に変換

    See Also
    --------
    forward : 学習時の順伝搬

    predict : 推論時の順伝搬(バッチ処理はしない)

    Note
    ----
    学習時と推論時で decoder の挙動が異なるので別々でメソッドを定義する
    """
    def __init__(self, vocab_size, hidden_size=300):
        super(Text2TextModel, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.embedding = Embedding(vocab_size, hidden_size)
        self.encoder = LSTM(
            input_size = self.hidden_size,
            hidden_size = self.hidden_size,
            num_layers = 1,
            bias = True,
            batch_first = True,
            dropout = 0,
            bidirectional = False
        )
        self.decoder = LSTM(
            input_size = self.hidden_size,
            hidden_size = self.hidden_size,
            num_layers = 1,
            bias = True,
            batch_first = True,
            dropout = 0,
            bidirectional = False
        )
        self.output = Linear(
            in_features = self.hidden_size,
            out_features = self.vocab_size
        )
    
    def forward(self, X, Y, device='cpu'):
        """学習時の順伝搬
        Parameters
        ----------
        X : Tensor[long]
            encoder の入力(batch_size, sequence_length)
        Y : Tensor[long]
            decoder の入力(batch_size, sequence_length)
        device : str
            実行するデバイス(cpu or cuda)の指定
        """
        h = torch.zeros(1, len(X), self.hidden_size).to(device) # 隠れ状態の初期化
        c = torch.zeros(1, len(X), self.hidden_size).to(device)
        encoder_i = self.embedding(X) # encoder の入力列の単語埋め込み
        decoder_i = self.embedding(Y) # decoder の入力列の単語埋め込み
        _, (h, c) = self.encoder(encoder_i, (h, c)) 
        o, _ = self.decoder(decoder_i, (h, c))
        o = self.output(o) # logit の計算

        return o

    @torch.inference_mode()
    def predict(self, X, device='cpu', max_length=64):
        """推論時の順伝搬
        Parameters
        ----------
        X : Tensor[long]
            encoder の入力(batch_size, sequence_length)
        device : str
            実行するデバイス(cpu or cuda)の指定
        max_length : int
            生成する系列の最大長
        """
        pred = [1] # SOS トークンを最初に入れる(本当はvocab[SOS_TOKEN]で入れるのが望ましい)
        h = torch.zeros(1, self.hidden_size).to(device) # 隠れ状態の初期化
        c = torch.zeros(1, self.hidden_size).to(device) # 隠れ状態の初期化
        encoder_i = self.embedding(X) # 入力列の埋め込み
        _, (h, c) = self.encoder(encoder_i, (h, c))
        while len(pred) <= max_length and pred[-1] != 2: # EOS トークンが出力されるか最大長に達するまで生成
            decoder_i = self.embedding(torch.Tensor(pred).long().to(device))
            o, _ = self.decoder(decoder_i, (h, c))
            logits = self.output(o[-1, :])
            pred.append(torch.argmax(logits).item()) # 最も高い確率だった単語を生成結果とする
        return pred

# %% [markdown]
# ## 問題1
# ---
# RNNを使用したときの実装と非常に似ていますが，LSTMとRNNの違い(理論面は別でやっているので，実装の部分を中心に)を教えてください．

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
    
    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
tokenized_concepts = [torch.Tensor([vocab[j] if j in vocab else vocab[UNK_TOKEN] for j in i]).long() for i in concepts]
tokenized_targets = [torch.Tensor([vocab[SOS_TOKEN]] + [vocab[j] if j in vocab else vocab[UNK_TOKEN] for j in nltk.tokenize.word_tokenize(i)] + [vocab[EOS_TOKEN]]).long() for i in targets]

# %%
train_dataset = MyDataset(tokenized_concepts, tokenized_targets)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=lambda x: [[i[0] for i in x], [i[1] for i in x]])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' # colabo では tpu も使用できますが，使用方法は自分で調べてみてください

lstm = Text2TextModel(len(vocab)).to(device)
optimizer = Adam(lstm.parameters(), lr=1e-3)
criterion = CrossEntropyLoss()
MAX_EPOCH = 15

loss_history = list()

for epoch in range(1, MAX_EPOCH+1):
    for batch_X, batch_Y in tqdm(dataloader):
        optimizer.zero_grad(set_to_none=True)
        encoder_input = pad_sequence(batch_X, batch_first=True).to(device)
        decoder_input = pad_sequence([i[:-1:] for i in batch_Y], batch_first=True).to(device)
        target = pad_sequence([i[1::] for i in batch_Y], batch_first=True).to(device)

        o = lstm(encoder_input, decoder_input, device)
        o = o.view(o.shape[0]*o.shape[1], -1) # CrossEntropyLoss の入力用に shape を変更
        target = target.view(o.shape[0], )
        loss = criterion(o, target)
        loss.backward()
        
        loss_history.append(loss.item())

        optimizer.step()
    train_loss = torch.mean(torch.Tensor(loss_history[-len(dataloader):])).item()
    print(f'{epoch=} | {train_loss=:.5f}')
# Out:
# 100%|██████████| 2106/2106 [00:27<00:00, 76.14it/s]
# epoch=1 | train_loss=2.85527
# 100%|██████████| 2106/2106 [00:28<00:00, 74.68it/s]
# epoch=2 | train_loss=1.96522
# 100%|██████████| 2106/2106 [00:27<00:00, 75.73it/s]
# epoch=3 | train_loss=1.60773
# 100%|██████████| 2106/2106 [00:27<00:00, 75.92it/s]
# epoch=4 | train_loss=1.37540
# 100%|██████████| 2106/2106 [00:27<00:00, 75.72it/s]
# epoch=5 | train_loss=1.20361
# 100%|██████████| 2106/2106 [00:27<00:00, 75.64it/s]
# epoch=6 | train_loss=1.06409
# 100%|██████████| 2106/2106 [00:27<00:00, 75.58it/s]
# epoch=7 | train_loss=0.95592
# 100%|██████████| 2106/2106 [00:27<00:00, 75.98it/s]
# epoch=8 | train_loss=0.86431
# 100%|██████████| 2106/2106 [00:27<00:00, 75.77it/s]
# epoch=9 | train_loss=0.78353
# 100%|██████████| 2106/2106 [00:27<00:00, 75.75it/s]
# epoch=10 | train_loss=0.71727
# 100%|██████████| 2106/2106 [00:27<00:00, 75.63it/s]
# epoch=11 | train_loss=0.65767
# 100%|██████████| 2106/2106 [00:27<00:00, 75.89it/s]
# epoch=12 | train_loss=0.60473
# 100%|██████████| 2106/2106 [00:27<00:00, 75.77it/s]
# epoch=13 | train_loss=0.56012
# 100%|██████████| 2106/2106 [00:27<00:00, 75.69it/s]
# epoch=14 | train_loss=0.52153
# 100%|██████████| 2106/2106 [00:27<00:00, 75.63it/s]
# epoch=15 | train_loss=0.48557

# %%
def decode(ids, vocab):
    """idのリストから文字列に変換
    Parameters
    ----------
    ids : list[int]
        変換対象の id のリスト
    vocab : dict[str, int]
        変換に使用する語彙の辞書
    """
    vocab_rev = {j:i for i, j in vocab.items()} # id -> word の変換に使いたいので辞書の key, value を交換
    decoded_sent = list()
    for id in ids:
        decoded_sent.append(vocab_rev[id]) # 存在しない id は入力されないことを前提にしている．これに対処する場合は場合分けするか，default Dict を使う
    return decoded_sent

# %%
def predict(idx):
    """学習用データの idx 番目 concepts から文を生成
    Parameters
    ----------
    idx : int
        学習用データの何番目を使用するか指定する整数
    """
    x = decode(train_dataset[idx][0].tolist(), vocab)
    true_y = decode(train_dataset[idx][1].tolist(), vocab)

    pred = lstm.predict(train_dataset[idx][0].to(device), device=device)
    pred_y = decode(pred, vocab)

    return x, true_y, pred_y

# %%
skip_keywords = list()
for i in range(1000):
    x, true_y, pred_y = predict(i)
    if x in skip_keywords:
        continue
    else:
        skip_keywords.append(x)
    score = sum([1 if w in pred_y else 0 for w in x])

    if score > 2:
        print('='*30+f'{score=}'+'='*30)
        print(f'idx={i}')
        print(f'keywords={x}')
        print(f'true sentense={true_y}')
        print(f'predicted sentense={pred_y}')
# Out:
# ==============================score=3==============================
# idx=39
# keywords=['lake', 'shore', 'canoe']
# true sentense=['<s>', 'canoe', 'on', 'a', 'shore', 'of', 'lake', '.', '</s>']
# predicted sentense=['<s>', 'canoe', 'on', 'shore', 'with', 'lake', 'in', 'autumn', '</s>']
# ==============================score=3==============================
# idx=42
# keywords=['mountain', 'skier', 'way']
# true sentense=['<s>', 'A', 'skier', 'on', 'his', 'way', 'to', 'the', 'mountain', '.', '</s>']
# predicted sentense=['<s>', 'A', 'skier', 'making', 'her', 'way', 'down', 'a', 'snowy', 'mountain', '.', '</s>']
# ==============================score=3==============================
# idx=72
# keywords=['station', 'stop', 'train']
# true sentense=['<s>', 'train', 'is', 'stopped', 'at', 'a', 'station', '</s>']
# predicted sentense=['<s>', 'A', 'train', 'stopped', 'at', 'the', 'station', 'next', 'to', 'a', 'stop', '.', '</s>']
# ==============================score=3==============================
# idx=120
# keywords=['beach', 'time', 'spend']
# true sentense=['<s>', 'tourists', 'spend', 'time', 'on', 'a', 'beach', '</s>']
# predicted sentense=['<s>', 'people', 'spend', 'a', 'time', 'at', 'the', 'beach', '</s>']
# ==============================score=3==============================
# idx=147
# keywords=['hospital', 'patient', 'nurse']
# true sentense=['<s>', 'nurse', 'with', 'a', 'patient', 'in', 'the', 'hospital', '</s>']
# predicted sentense=['<s>', 'nurse', 'visiting', 'the', 'patient', 'in', 'hospital', '</s>']
# ==============================score=3==============================
# idx=192
# keywords=['clock', 'room', 'wall']
# true sentense=['<s>', 'A', 'small', 'clock', 'on', 'a', 'wall', 'in', 'a', 'room', '.', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'clock', 'on', 'the', 'wall', '.', '</s>']
# ==============================score=3==============================
# idx=215
# keywords=['herd', 'pasture', 'sheep']
# true sentense=['<s>', 'herd', 'of', 'sheep', 'on', 'a', 'pasture', '.', '</s>']
# predicted sentense=['<s>', 'a', 'herd', 'of', 'sheep', 'on', 'pasture', 'to', 'pasture', 'in', 'the', 'field', '</s>']
# ==============================score=3==============================
# idx=242
# keywords=['skateboarder', 'skate', 'park']
# true sentense=['<s>', 'A', 'skateboarder', 'skating', 'at', 'a', 'skate', 'park', '.', '</s>']
# predicted sentense=['<s>', 'A', 'skateboarder', 'skates', 'next', 'to', 'a', 'ledge', 'in', 'a', 'skate', 'park', '.', '</s>']
# ==============================score=3==============================
# idx=274
# keywords=['carpet', 'wall', 'room']
# true sentense=['<s>', 'A', 'room', 'with', 'stone', 'walls', 'and', 'colorful', 'carpet', '.', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'carpet', 'on', 'the', 'wall', 'and', 'a', 'carpet', 'of', 'room', '.', '</s>']
# ==============================score=3==============================
# idx=314
# keywords=['color', 'die', 'hair']
# true sentense=['<s>', 'if', 'i', 'ever', 'die', 'my', 'hair', 'it', 'gon', 'na', 'be', 'this', 'color', '</s>']
# predicted sentense=['<s>', 'if', 'i', 'ever', 'die', 'my', 'hair', 'it', 'gon', 'na', 'be', 'this', 'color', '</s>']
# ==============================score=3==============================
# idx=422
# keywords=['band', 'audience', 'concert']
# true sentense=['<s>', 'An', 'audience', 'at', 'a', 'live', 'concert', 'cheering', 'on', 'the', 'band', '.', '</s>']
# predicted sentense=['<s>', 'An', 'audience', 'awaits', 'a', 'concert', 'from', 'a', 'band', '.', '</s>']
# ==============================score=3==============================
# idx=469
# keywords=['plate', 'table', 'pizza']
# true sentense=['<s>', 'a', 'plate', 'of', 'pizza', 'on', 'a', 'table', '</s>']
# predicted sentense=['<s>', 'A', 'pizza', 'on', 'a', 'plate', 'with', 'a', 'table', 'and', 'condiments', 'on', 'it', '.', '</s>']
# ==============================score=3==============================
# idx=475
# keywords=['room', 'couch', 'chair']
# true sentense=['<s>', 'A', 'couch', 'and', 'a', 'chair', 'in', 'a', 'room', '.', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'couch', 'chair', ',', 'chairs', 'and', 'a', 'television', '.', '</s>']
# ==============================score=3==============================
# idx=484
# keywords=['building', 'clock', 'top']
# true sentense=['<s>', 'a', 'clock', 'on', 'the', 'top', 'of', 'a', 'building', '</s>']
# predicted sentense=['<s>', 'A', 'building', 'with', 'a', 'clock', 'on', 'top', 'and', 'a', 'gold', 'and', 'a', 'white', 'clock', '.', '</s>']
# ==============================score=3==============================
# idx=490
# keywords=['wall', 'toilet', 'bathroom']
# true sentense=['<s>', 'A', 'toilet', 'in', 'a', 'bathroom', 'next', 'to', 'a', 'wall', '.', '</s>']
# predicted sentense=['<s>', 'A', 'bathroom', 'has', 'a', 'white', 'toilet', 'and', 'wall', 'with', 'a', 'blue', 'wall', 'mounted', 'inside', '.', '</s>']
# ==============================score=3==============================
# idx=493
# keywords=['track', 'train', 'station']
# true sentense=['<s>', 'a', 'train', 'on', 'track', 'at', 'station', '</s>']
# predicted sentense=['<s>', 'A', 'train', 'on', 'a', 'track', 'in', 'a', 'station', '.', '</s>']
# ==============================score=3==============================
# idx=496
# keywords=['pizza', 'piece', 'plate']
# true sentense=['<s>', 'A', 'piece', 'of', 'pizza', 'is', 'on', 'a', 'plate', '</s>']
# predicted sentense=['<s>', 'A', 'piece', 'of', 'pizza', 'on', 'a', 'plate', '</s>']
# ==============================score=3==============================
# idx=526
# keywords=['sauce', 'pizza', 'cheese']
# true sentense=['<s>', 'A', 'plate', 'of', 'pizza', 'with', 'cheese', 'and', 'sauce', '.', '</s>']
# predicted sentense=['<s>', 'A', 'large', 'pizza', 'with', 'cheese', 'and', 'sauce', 'on', 'a', 'blue', 'plate', '.', '</s>']
# ==============================score=3==============================
# idx=529
# keywords=['tree', 'train', 'track']
# true sentense=['<s>', 'train', 'tracks', 'through', 'the', 'trees', '</s>']
# predicted sentense=['<s>', 'A', 'train', 'on', 'a', 'track', 'near', 'a', 'tree', '.', '</s>']
# ==============================score=3==============================
# idx=535
# keywords=['track', 'building', 'train']
# true sentense=['<s>', 'a', 'train', 'on', 'a', 'track', 'near', 'a', 'building', '</s>']
# predicted sentense=['<s>', 'A', 'train', 'on', 'a', 'track', 'near', 'a', 'building', 'with', 'a', 'massive', 'building', '.', '</s>']
# ==============================score=3==============================
# idx=550
# keywords=['sheep', 'field', 'herd']
# true sentense=['<s>', 'herd', 'of', 'sheep', 'in', 'a', 'field', '</s>']
# predicted sentense=['<s>', 'A', 'herd', 'of', 'sheep', 'and', 'various', 'sheep', 'are', 'grazing', 'in', 'the', 'green', 'field', '.', '</s>']
# ==============================score=3==============================
# idx=568
# keywords=['bathroom', 'tub', 'shower']
# true sentense=['<s>', 'A', 'bathroom', 'has', 'a', 'tub', 'but', 'no', 'shower', '.', '</s>']
# predicted sentense=['<s>', 'A', 'bathroom', 'has', 'a', 'tub', ',', 'and', 'shower', '.', '</s>']
# ==============================score=3==============================
# idx=571
# keywords=['track', 'city', 'train']
# true sentense=['<s>', 'train', 'on', 'the', 'track', 'in', 'city', '</s>']
# predicted sentense=['<s>', 'A', 'train', 'rounds', 'the', 'track', 'in', 'a', 'city', '</s>']
# ==============================score=3==============================
# idx=588
# keywords=['sheep', 'field', 'flock']
# true sentense=['<s>', 'flock', 'of', 'sheep', 'in', 'a', 'field', '</s>']
# predicted sentense=['<s>', 'flock', 'of', 'sheep', 'grazing', 'on', 'the', 'green', 'field', '.', '</s>']
# ==============================score=3==============================
# idx=594
# keywords=['room', 'couch', 'fireplace']
# true sentense=['<s>', 'A', 'couch', 'in', 'a', 'living', 'room', 'by', 'a', 'fireplace', '.', '</s>']
# predicted sentense=['<s>', 'A', 'living', 'room', 'with', 'a', 'couch', 'and', 'a', 'fireplace', '.', '</s>']
# ==============================score=3==============================
# idx=605
# keywords=['table', 'topping', 'pizza']
# true sentense=['<s>', 'a', 'pizza', 'with', 'toppings', 'on', 'it', 'on', 'a', 'table', '</s>']
# predicted sentense=['<s>', 'A', 'pizza', 'with', 'topping', 'that', 'has', 'been', 'served', 'to', 'a', 'table', '.', '</s>']
# ==============================score=3==============================
# idx=611
# keywords=['fish', 'sale', 'market']
# true sentense=['<s>', 'fish', 'for', 'sale', 'the', 'market', '</s>']
# predicted sentense=['<s>', 'fish', 'market', 'the', 'fish', 'for', 'sale', '</s>']
# ==============================score=3==============================
# idx=617
# keywords=['coffee', 'donut', 'cup']
# true sentense=['<s>', 'a', 'cup', 'of', 'coffee', 'and', 'a', 'donut', '</s>']
# predicted sentense=['<s>', 'A', 'donut', 'and', 'a', 'cup', 'of', 'coffee', '.', '</s>']
# ==============================score=3==============================
# idx=620
# keywords=['cattle', 'field', 'herd']
# true sentense=['<s>', 'herd', 'of', 'cattle', 'in', 'a', 'field', '</s>']
# predicted sentense=['<s>', 'A', 'herd', 'of', 'cattle', 'in', 'a', 'field', 'next', 'to', 'each', 'other', '.', '</s>']
# ==============================score=3==============================
# idx=641
# keywords=['couch', 'wall', 'room']
# true sentense=['<s>', 'a', 'living', 'room', 'with', 'couches', 'near', 'a', 'wall', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'couch', 'and', 'chairs', 'and', 'a', 'wall', '.', '</s>']
# ==============================score=3==============================
# idx=668
# keywords=['family', 'celebrate', 'holiday']
# true sentense=['<s>', 'A', 'family', 'celebrating', 'a', 'holiday', '</s>']
# predicted sentense=['<s>', 'families', 'and', 'family', 'celebrate', 'a', 'group', 'of', 'holiday', '</s>']
# ==============================score=3==============================
# idx=680
# keywords=['building', 'wall', 'clock']
# true sentense=['<s>', 'A', 'clock', 'is', 'on', 'the', 'wall', 'of', 'a', 'building', '.', '</s>']
# predicted sentense=['<s>', 'A', 'clock', 'on', 'a', 'wall', 'next', 'to', 'a', 'building', '.', '</s>']
# ==============================score=3==============================
# idx=695
# keywords=['bathtub', 'bathroom', 'shower']
# true sentense=['<s>', 'bathtub', 'and', 'shower', 'in', 'the', 'new', 'bathroom', '</s>']
# predicted sentense=['<s>', 'A', 'bathroom', 'with', 'a', 'bathtub', ',', 'shower', 'and', 'a', 'mirror', '.', '</s>']
# ==============================score=3==============================
# idx=735
# keywords=['plate', 'sauce', 'meat']
# true sentense=['<s>', 'A', 'plate', 'of', 'meat', ',', 'vegetables', 'and', 'a', 'sauce', '</s>']
# predicted sentense=['<s>', 'A', 'white', 'plate', 'topped', 'with', 'meat', ',', 'vegetables', 'and', 'sauce', '.', '</s>']
# ==============================score=3==============================
# idx=738
# keywords=['home', 'room', 'couch']
# true sentense=['<s>', 'plush', 'gray', 'couch', 'in', 'the', 'living', 'room', 'of', 'the', 'home', '</s>']
# predicted sentense=['<s>', 'A', 'living', 'room', 'with', 'a', 'couch', 'and', 'a', 'home', '.', '</s>']
# ==============================score=3==============================
# idx=750
# keywords=['cup', 'coffee', 'doughnut']
# true sentense=['<s>', 'a', 'cup', 'of', 'coffee', 'next', 'to', 'a', 'doughnut', '</s>']
# predicted sentense=['<s>', 'a', 'cup', 'of', 'coffee', 'at', 'a', 'doughnut', 'covered', 'in', 'toppings', '</s>']
# ==============================score=3==============================
# idx=761
# keywords=['herd', 'grass', 'sheep']
# true sentense=['<s>', 'A', 'herd', 'of', 'sheep', 'roam', 'in', 'the', 'grass', '.', '</s>']
# predicted sentense=['<s>', 'A', 'herd', 'of', 'sheep', 'lying', 'in', 'the', 'grass', '.', '</s>']
# ==============================score=3==============================
# idx=770
# keywords=['bath', 'bathroom', 'shower']
# true sentense=['<s>', 'bathroom', 'with', 'shower', 'over', 'bath', '</s>']
# predicted sentense=['<s>', 'the', 'bathroom', 'has', 'a', 'shower', 'over', 'the', 'bath', '.', '</s>']
# ==============================score=3==============================
# idx=782
# keywords=['beach', 'fisherman', 'net']
# true sentense=['<s>', 'fishermen', 'with', 'nets', 'on', 'the', 'beach', '</s>']
# predicted sentense=['<s>', 'a', 'fisherman', 'throws', 'his', 'net', 'on', 'beach', '</s>']
# ==============================score=3==============================
# idx=785
# keywords=['airplane', 'tarmac', 'airport']
# true sentense=['<s>', 'airplane', 'on', 'tarmac', 'at', 'an', 'airport', '</s>']
# predicted sentense=['<s>', 'An', 'airplane', 'on', 'tarmac', 'at', 'airport', "'s", 'tarmac', '</s>']
# ==============================score=3==============================
# idx=788
# keywords=['bathroom', 'floor', 'tile']
# true sentense=['<s>', 'white', 'tiles', 'on', 'a', 'floor', 'in', 'bathroom', '</s>']
# predicted sentense=['<s>', 'A', 'small', 'bathroom', 'including', 'tile', 'and', 'floor', '.', '</s>']
# ==============================score=3==============================
# idx=806
# keywords=['bathroom', 'toilet', 'shelf']
# true sentense=['<s>', 'A', 'small', 'bathroom', 'and', 'toilet', 'and', 'a', 'shelf', '.', '</s>']
# predicted sentense=['<s>', 'A', 'bathroom', 'has', 'a', 'toilet', ',', 'and', 'a', 'shelf', 'or', 'rug', '.', '</s>']
# ==============================score=3==============================
# idx=837
# keywords=['beach', 'boat', 'sea']
# true sentense=['<s>', 'boat', 'on', 'the', 'beach', 'at', 'sea', '</s>']
# predicted sentense=['<s>', 'boat', 'on', 'the', 'beach', 'in', 'a', 'sea', '</s>']
# ==============================score=3==============================
# idx=842
# keywords=['plane', 'land', 'airport']
# true sentense=['<s>', 'a', 'plane', 'lands', 'on', 'the', 'airport', '</s>']
# predicted sentense=['<s>', 'a', 'plane', 'comes', 'to', 'land', 'at', 'airport', '</s>']
# ==============================score=3==============================
# idx=875
# keywords=['flock', 'pasture', 'sheep']
# true sentense=['<s>', 'a', 'flock', 'of', 'sheep', 'in', 'the', 'pasture', '</s>']
# predicted sentense=['<s>', 'flock', 'of', 'multicolored', 'sheep', 'in', 'the', 'pasture', '</s>']
# ==============================score=3==============================
# idx=901
# keywords=['vegetable', 'fish', 'plate']
# true sentense=['<s>', 'fish', 'and', 'vegetable', 'in', 'the', 'plate', '</s>']
# predicted sentense=['<s>', 'A', 'vegetable', 'plate', 'of', 'fish', ',', 'including', 'broccoli', 'and', 'cheese', '.', '</s>']
# ==============================score=3==============================
# idx=944
# keywords=['clock', 'church', 'tower']
# true sentense=['<s>', 'A', 'clock', 'on', 'a', 'tower', 'at', 'a', 'church', '.', '</s>']
# predicted sentense=['<s>', 'A', 'clock', 'in', 'the', 'tower', 'of', 'a', 'church', '</s>']
# ==============================score=3==============================
# idx=947
# keywords=['boat', 'harbor', 'city']
# true sentense=['<s>', 'these', 'boat', 'in', 'harbor', 'at', 'city', '</s>']
# predicted sentense=['<s>', 'a', 'boat', 'is', 'the', 'harbor', 'in', 'the', 'city', '</s>']
# ==============================score=3==============================
# idx=950
# keywords=['pitch', 'batter', 'catcher']
# true sentense=['<s>', 'A', 'batter', 'and', 'catcher', 'in', 'the', 'middle', 'of', 'a', 'pitch', '.', '</s>']
# predicted sentense=['<s>', 'A', 'pitch', 'is', 'delivered', 'as', 'the', 'batter', ',', 'catcher', ',', 'and', 'umpire', 'watch', '.', '</s>']
# ==============================score=3==============================
# idx=953
# keywords=['change', 'car', 'oil']
# true sentense=['<s>', 'A', 'man', 'changes', 'the', 'oil', 'in', 'a', 'car', '.', '</s>']
# predicted sentense=['<s>', 'it', 'is', 'a', 'change', 'of', 'oil', 'in', 'a', 'car', 'that', 'such', 'as', 'deity', 'can', 'be', 'made', 'up', '.', '</s>']
# ==============================score=3==============================
# idx=982
# keywords=['bathroom', 'shower', 'tile']
# true sentense=['<s>', 'A', 'bathroom', 'with', 'tile', 'and', 'a', 'shower', 'is', 'shown', '.', '</s>']
# predicted sentense=['<s>', 'A', 'bathroom', 'has', 'a', 'tile', 'and', 'a', 'shelf', 'or', 'shower', '.', '</s>']

# %% [markdown]
# # 検証データに対して予測してみる

# %%
valid_concepts= [i['concepts'] for i in dataset['validation']]
valid_targets= [i['target'] for i in dataset['validation']]

# %%
tokenized_valid_concepts = [torch.Tensor([vocab[j] if j in vocab else vocab[UNK_TOKEN] for j in i]).long() for i in valid_concepts]
tokenized_valid_targets = [torch.Tensor([vocab[SOS_TOKEN]] + [vocab[j] if j in vocab else vocab[UNK_TOKEN] for j in nltk.tokenize.word_tokenize(i)] + [vocab[EOS_TOKEN]]).long() for i in valid_targets]

# %%
valid_dataset = MyDataset(tokenized_valid_concepts, tokenized_valid_targets)

# %%
def predict_valid(idx):
    x = decode(valid_dataset[idx][0].tolist(), vocab)
    true_y = decode(valid_dataset[idx][1].tolist(), vocab)

    pred = lstm.predict(valid_dataset[idx][0].to(device), device=device)
    pred_y = decode(pred, vocab)

    return x, true_y, pred_y

# %%
skip_keywords = list()
for i in range(1000):
    x, true_y, pred_y = predict_valid(i)
    if x in skip_keywords:
        continue
    else:
        skip_keywords.append(x)
    score = sum([1 if w in pred_y else 0 for w in x])

    if score > 1:
        print('='*30+f'{score=}'+'='*30)
        print(f'idx={i}')
        print(f'keywords={x}')
        print(f'true sentense={true_y}')
        print(f'predicted sentense={pred_y}')
# Out:
# ==============================score=2==============================
# idx=8
# keywords=['cat', 'pet', 'couch']
# true sentense=['<s>', 'A', 'pet', 'cat', 'likes', 'to', 'sleep', 'on', 'a', 'couch', '.', '</s>']
# predicted sentense=['<s>', 'A', 'cat', 'floating', 'on', 'the', 'couch', 'of', 'the', 'small', 'home', '.', '</s>']
# ==============================score=2==============================
# idx=12
# keywords=['climb', 'building', 'side']
# true sentense=['<s>', 'The', 'mouse', 'climbed', 'the', 'side', 'of', 'the', 'building', '.', '</s>']
# predicted sentense=['<s>', 'A', 'boy', "'s", 'in', 'a', 'building', 'next', 'to', 'a', 'side', 'of', 'a', 'sheep', '.', '</s>']
# ==============================score=2==============================
# idx=70
# keywords=['hand', 'front', 'wave']
# true sentense=['<s>', 'A', 'girl', 'waved', 'her', 'hand', 'in', 'front', 'of', 'the', 'man', '.', '</s>']
# predicted sentense=['<s>', 'people', 'waving', 'their', 'own', 'hand', 'at', 'the', 'front', 'with', 'the', 'camera', 'and', 'the', 'camera', 'extended', 'closer', 'to', 'the', 'camera', 'and', 'yellow', 'butterfly', '</s>']
# ==============================score=2==============================
# idx=111
# keywords=['sit', 'cat', 'floor']
# true sentense=['<s>', 'The', 'cat', 'is', 'sitting', 'on', 'the', 'floor', '.', '</s>']
# predicted sentense=['<s>', 'A', 'cat', 'sits', 'on', 'the', 'floor', 'while', 'a', 'man', 'in', 'a', 'wheelchair', '.', '</s>']
# ==============================score=2==============================
# idx=123
# keywords=['wall', 'watch', 'stand']
# true sentense=['<s>', 'a', 'girl', 'stands', 'in', 'front', 'of', 'the', 'wall', 'watching', 'it', '</s>']
# predicted sentense=['<s>', 'A', 'girl', 'stands', 'proudly', 'at', 'a', 'wall', 'of', 'watch', '</s>']
# ==============================score=2==============================
# idx=125
# keywords=['eat', 'meal', 'prepare']
# true sentense=['<s>', 'A', 'child', 'eats', 'a', 'meal', 'her', 'mother', 'prepares', '.', '</s>']
# predicted sentense=['<s>', 'a', 'meal', 'is', 'a', 'good', 'time', 'to', 'eat', '</s>']
# ==============================score=2==============================
# idx=149
# keywords=['street', 'side', 'car']
# true sentense=['<s>', 'A', 'car', 'was', 'parked', 'on', 'the', 'side', 'of', 'the', 'street', '.', '</s>']
# predicted sentense=['<s>', 'car', 'on', 'either', 'side', 'of', 'a', 'car', 'in', 'a', 'city', '</s>']
# ==============================score=2==============================
# idx=195
# keywords=['pitcher', 'ball', 'pitch']
# true sentense=['<s>', 'The', 'pitcher', 'will', 'pitch', 'the', 'ball', '.', '</s>']
# predicted sentense=['<s>', 'pitcher', 'and', 'his', 'family', 'plays', 'the', 'pitch', '</s>']
# ==============================score=2==============================
# idx=220
# keywords=['gun', 'head', 'point']
# true sentense=['<s>', 'The', 'robber', 'pointed', 'the', 'gun', 'at', 'the', 'head', 'of', 'the', 'bank', 'manager', '.', '</s>']
# predicted sentense=['<s>', 'A', 'boy', 'puts', 'his', 'head', 'down', 'the', 'gun', 'at', 'the', 'top', '.', '</s>']
# ==============================score=2==============================
# idx=224
# keywords=['water', 'boat', 'dock']
# true sentense=['<s>', 'The', 'boat', 'in', 'the', 'water', 'was', 'docked', 'near', 'the', 'pier', '.', '</s>']
# predicted sentense=['<s>', 'a', 'small', 'pond', 'with', 'a', 'small', 'fishing', 'boat', 'in', 'the', 'water', '</s>']
# ==============================score=2==============================
# idx=241
# keywords=['game', 'score', 'player']
# true sentense=['<s>', 'In', 'a', 'soccer', 'game', 'players', 'score', 'goal', '</s>']
# predicted sentense=['<s>', 'football', 'player', 'revealed', 'the', 'final', 'by', 'the', 'game', '...', 'will', 'be', 'the', 'first', 'time', 'before', 'the', 'match', '.', '</s>']
# ==============================score=2==============================
# idx=307
# keywords=['tire', 'fix', 'bike']
# true sentense=['<s>', 'The', 'teen', 'had', 'to', 'fix', 'his', 'tire', 'on', 'the', 'bike', 'so', 'he', 'could', 'ride', 'it', '.', '</s>']
# predicted sentense=['<s>', 'A', 'man', 'and', 'his', 'young', 'girl', 'is', 'trying', 'to', 'fix', 'a', 'bike', 'during', 'the', 'auto', 'race', '.', '</s>']
# ==============================score=2==============================
# idx=319
# keywords=['bike', 'music', 'ride']
# true sentense=['<s>', 'The', 'boy', '<UNK>', 'to', 'music', 'on', 'his', 'bike', 'ride', '.', '</s>']
# predicted sentense=['<s>', 'The', 'man', 'is', 'collecting', 'up', 'of', 'the', 'bike', 'and', 'getting', 'a', 'music', '.', '</s>']
# ==============================score=2==============================
# idx=333
# keywords=['top', 'walk', 'dog']
# true sentense=['<s>', 'The', 'child', 'will', 'walk', 'to', 'the', 'top', 'of', 'the', 'hill', 'with', 'his', 'dog', '.', '</s>']
# predicted sentense=['<s>', 'A', 'dog', 'is', 'walking', 'with', 'a', 'top', 'of', 'the', 'top', '.', '</s>']
# ==============================score=2==============================
# idx=368
# keywords=['use', 'comb', 'hair']
# true sentense=['<s>', 'I', 'use', 'a', 'comb', 'to', 'fix', 'my', 'hair', '.', '</s>']
# predicted sentense=['<s>', 'use', 'the', 'hair', 'to', 'introduce', 'red', 'hair', '</s>']
# ==============================score=2==============================
# idx=376
# keywords=['view', 'ocean', 'boat']
# true sentense=['<s>', 'There', 'is', 'a', 'beautiful', 'view', 'of', 'the', 'ocean', 'from', 'a', 'boat', '.', '</s>']
# predicted sentense=['<s>', 'view', 'of', 'local', 'port', 'with', 'a', 'small', 'fishing', 'boat', 'in', 'the', 'distance', '</s>']
# ==============================score=2==============================
# idx=380
# keywords=['hit', 'team', 'ball']
# true sentense=['<s>', 'Johnny', 'hit', 'the', 'ball', 'to', 'score', 'on', 'the', 'other', 'team', '.', '</s>']
# predicted sentense=['<s>', 'sports', 'team', 'will', 'find', 'the', 'ball', 'as', 'sports', 'team', 'could', 'move', 'out', 'in', 'front', 'of', 'the', 'darkness', '</s>']
# ==============================score=2==============================
# idx=473
# keywords=['eat', 'room', 'food']
# true sentense=['<s>', 'The', 'family', 'went', 'to', 'the', 'dining', 'room', 'to', 'eat', 'their', 'food', '.', '</s>']
# predicted sentense=['<s>', 'A', 'girl', 'eating', 'a', 'living', 'room', 'with', 'a', 'lot', 'of', 'food', 'and', 'other', 'people', 'can', 'not', 'it', '.', '</s>']
# ==============================score=2==============================
# idx=531
# keywords=['couple', 'ride', 'street']
# true sentense=['<s>', 'A', 'couple', 'rides', 'down', 'the', 'street', '.', '</s>']
# predicted sentense=['<s>', 'couple', 'in', 'the', 'street', 'of', 'the', 'city', '</s>']
# ==============================score=2==============================
# idx=577
# keywords=['front', 'mirror', 'room']
# true sentense=['<s>', 'she', 'can', 'stay', 'in', 'front', 'of', 'the', 'mirror', 'in', 'her', 'room', 'all', 'day', 'long', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'rug', 'and', 'it', 'in', 'front', 'of', 'a', 'small', 'doll', '.', '</s>']
# ==============================score=3==============================
# idx=581
# keywords=['side', 'park', 'car']
# true sentense=['<s>', 'The', 'car', 'parks', 'on', 'the', 'right', 'side', 'of', 'the', 'street', '.', '</s>']
# predicted sentense=['<s>', 'A', 'large', 'car', 'with', 'a', 'large', 'green', 'clock', 'on', 'the', 'side', 'of', 'the', 'park', '.', '</s>']
# ==============================score=2==============================
# idx=585
# keywords=['table', 'house', 'sit']
# true sentense=['<s>', 'The', 'guests', 'wanted', 'to', 'sit', 'at', 'the', 'table', 'in', 'their', 'friends', 'new', 'house', '.', '</s>']
# predicted sentense=['<s>', 'a', 'large', 'sitting', 'room', 'on', 'a', 'table', 'at', 'the', 'foot', 'of', 'a', 'house', 'and', 'early', 'hours', '</s>']
# ==============================score=2==============================
# idx=650
# keywords=['jump', 'water', 'lake']
# true sentense=['<s>', 'A', 'boy', 'jumps', 'over', 'the', 'water', 'in', 'the', 'lake', '</s>']
# predicted sentense=['<s>', 'young', 'man', 'on', 'the', 'lake', 'in', 'the', 'water', 'and', 'the', 'air', 'seen', 'being', 'seen', 'on', 'the', 'air', 'slopes', '</s>']
# ==============================score=2==============================
# idx=653
# keywords=['couple', 'swim', 'pool']
# true sentense=['<s>', 'The', 'couple', 'love', 'to', 'swim', 'in', 'their', 'new', 'pool', '.', '</s>']
# predicted sentense=['<s>', 'a', 'couple', 'in', 'a', 'swimming', 'pool', 'beside', 'a', 'pool', '.', '</s>']
# ==============================score=2==============================
# idx=698
# keywords=['ride', 'horse', 'tree']
# true sentense=['<s>', 'The', 'girls', 'took', 'a', 'ride', 'on', 'the', 'horses', 'to', 'the', 'tree', 'by', 'the', 'lake', '.', '</s>']
# predicted sentense=['<s>', 'horse', 'and', 'a', 'horse', 'on', 'a', 'tree', '</s>']
# ==============================score=2==============================
# idx=706
# keywords=['canoe', 'body', 'water']
# true sentense=['<s>', 'a', 'man', 'sees', 'the', 'body', 'of', 'a', 'boy', 'in', 'a', 'canoe', 'on', 'the', 'water', '</s>']
# predicted sentense=['<s>', 'a', 'man', 'is', 'getting', 'into', 'a', 'canoe', 'on', 'the', 'water', '</s>']
# ==============================score=2==============================
# idx=733
# keywords=['toss', 'kid', 'ball']
# true sentense=['<s>', 'The', 'kid', 'tossed', 'the', 'ball', 'across', 'the', 'court', '.', '</s>']
# predicted sentense=['<s>', 'A', 'kid', 'is', 'in', 'a', 'white', 'and', 'a', 'ball', '.', '</s>']
# ==============================score=2==============================
# idx=751
# keywords=['restaurant', 'table', 'food']
# true sentense=['<s>', 'The', 'food', 'was', 'served', 'on', 'the', 'table', 'at', 'the', 'restaurant', '.', '</s>']
# predicted sentense=['<s>', 'coloured', 'and', 'white', 'restaurant', 'are', 'seen', 'in', 'the', 'table', 'of', 'a', 'variety', 'of', 'colors', '.', '</s>']
# ==============================score=2==============================
# idx=795
# keywords=['street', 'dog', 'leash']
# true sentense=['<s>', 'The', 'dog', 'is', 'walking', 'down', 'the', 'street', 'on', 'a', 'leash', '.', '</s>']
# predicted sentense=['<s>', 'wild', 'dog', 'in', 'a', 'small', 'deserted', 'street', 'in', 'autumn', '</s>']
# ==============================score=2==============================
# idx=817
# keywords=['water', 'jump', 'run']
# true sentense=['<s>', 'A', 'group', 'of', 'kids', 'run', 'and', 'jump', 'into', 'the', 'water', '.', '</s>']
# predicted sentense=['<s>', 'Two', 'young', 'boys', 'play', 'a', 'run', 'to', 'separate', 'into', 'the', 'water', 'to', 'cool', 'down', '</s>']
# ==============================score=2==============================
# idx=833
# keywords=['couple', 'kid', 'room']
# true sentense=['<s>', 'The', 'couple', 'in', 'the', 'room', 'has', 'a', 'kid', '.', '</s>']
# predicted sentense=['<s>', 'couple', 'in', 'a', 'small', 'entry', 'light', 'at', 'a', 'gallery', 'start', 'to', 'your', 'living', 'room', '.', '</s>']
# ==============================score=3==============================
# idx=858
# keywords=['street', 'front', 'car']
# true sentense=['<s>', 'The', 'girl', 'parked', 'her', 'car', 'on', 'the', 'side', 'of', 'the', 'street', 'in', 'front', 'of', 'the', 'house', '.', '</s>']
# predicted sentense=['<s>', 'car', 'and', 'car', 'in', 'front', 'of', 'a', 'city', 'street', '</s>']
# ==============================score=2==============================
# idx=866
# keywords=['lady', 'fix', 'hair']
# true sentense=['<s>', 'A', 'lady', 'fixes', 'her', 'hair', '.', '</s>']
# predicted sentense=['<s>', 'A', 'lady', 'in', 'red', 'and', 'yellow', 'hair', 'is', 'resting', '.', '</s>']
# ==============================score=2==============================
# idx=870
# keywords=['floor', 'room', 'stand']
# true sentense=['<s>', 'The', 'tile', 'floor', 'in', 'the', 'room', 'was', 'broken', ',', 'so', 'the', 'students', 'could', 'no', 'longer', 'stand', 'on', 'it', '.', '</s>']
# predicted sentense=['<s>', 'A', 'room', 'with', 'a', 'wooden', 'floor', 'and', 'a', 'wooden', 'clock', 'on', 'the', 'desk', '.', '</s>']
# ==============================score=2==============================
# idx=889
# keywords=['log', '<UNK>', 'wood']
# true sentense=['<s>', 'A', 'man', 'uses', 'an', 'ax', 'to', '<UNK>', 'logs', 'into', 'fire', 'wood', '.', '</s>']
# predicted sentense=['<s>', 'isolated', 'on', 'white', 'with', 'a', 'log', 'and', 'wood', 'in', '</s>']
# ==============================score=2==============================
# idx=891
# keywords=['lay', 'bed', 'room']
# true sentense=['<s>', 'The', 'girls', 'goes', 'to', 'her', 'room', 'to', 'lay', 'in', 'bed', '.', '</s>']
# predicted sentense=['<s>', 'A', 'woman', 'in', 'bed', 'is', 'laying', 'down', 'in', 'a', 'room', 'with', 'a', 'red', 'couch', '.', '</s>']
# ==============================score=2==============================
# idx=927
# keywords=['mother', 'sit', 'chair']
# true sentense=['<s>', 'The', 'mother', 'sits', 'on', 'a', 'chair', '.', '</s>']
# predicted sentense=['<s>', 'A', 'mother', 'sitting', 'on', 'her', 'chair', 'at', 'the', 'camera', '.', '</s>']
# ==============================score=2==============================
# idx=992
# keywords=['paint', 'worker', 'wall']
# true sentense=['<s>', 'The', 'worker', 'painted', 'the', 'wall', 'white', 'yesterday', '.', '</s>']
# predicted sentense=['<s>', 'A', 'worker', 'painted', 'white', 'acrylic', 'painting', 'on', 'the', 'wall', '.', '</s>']

# %% [markdown]
# ## 問題2
# ---
# GRU を使用した実装をしてみてください
